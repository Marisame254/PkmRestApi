# %%
import pandas as pd

# %%
data = pd.read_csv("data/pokemon.csv")
data
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
data.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
pokemons = data[["pokedex_number", "name", "type1", "hp", "attack", 
                    "defense", "sp_attack", "sp_defense", "speed"]]
pokemons['type1'] = data['type1'].astype(str) + " " + data['type2'].astype(str)
pokemons = pokemons.rename(columns = {'pokedex_number':'id'})

pokemons.to_csv("data/pokemons.csv", index=False)
pokemons.head()
# Out:
# /tmp/ipykernel_15878/3179260625.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pokemons['type1'] = data['type1'].astype(str) + " " + data['type2'].astype(str)
#    id        name         type1  hp  attack  defense  sp_attack  sp_defense  \
# 0   1   Bulbasaur  grass poison  45      49       49         65          65
# 1   2     Ivysaur  grass poison  60      62       63         80          80
# 2   3    Venusaur  grass poison  80     100      123        122         120
# 3   4  Charmander      fire nan  39      52       43         60          50
# 4   5  Charmeleon      fire nan  58      64       58         80          65
#
#    speed
# 0     45
# 1     60
# 2     80
# 3     65
# 4     80
